# %%
import os
os.chdir('/Users/fionaspuler/Documents/GitHub/RMM-VAE/')

import sys
sys.path[0]='/Users/fionaspuler/Documents/GitHub/RMM-VAE/'

# %%
from keras.layers import Lambda, Input, Dense, Reshape, Dropout
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K
from keras.constraints import unit_norm

from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, homogeneity_score, fowlkes_mallows_score 
from sklearn.metrics import completeness_score, silhouette_score, mean_squared_error, adjusted_rand_score

import pandas as pd
import numpy as np
import xarray as xr

from scipy import stats
import xesmf as xe
from math import ceil

import argparse
import os

import matplotlib
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy

#from sklearn.metrics import silhouette_score

import clustering_functions as cf
# Out:
# 2023-10-12 22:27:12.795828: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
execfile('pre_processing.py')
# Out:
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_morestats.py:933: RuntimeWarning: overflow encountered in power
#   variance = np.var(data**lmb / lmb, axis=0)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:213: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py:2417: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:236: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)

# %% [markdown]
# **import model specifications saved in yaml file**

# %%
import yaml
from yaml import CLoader as Loader
stream = open("model_specifications/RMM-VAE/v1/v5.yaml", 'r')
dictionary = yaml.load(stream, Loader=Loader)

filepath = dictionary['filepath']

original_dim = dictionary['original_dim']
inputdim1 = dictionary['inputdim1']
inputdim2 = dictionary['inputdim2']

latent_dim = dictionary['latent_dim']

activation_function = dictionary['activation_function']

dim_layer1 = dictionary['dim_layer1']
dim_layer2 = dictionary['dim_layer2']

cat_dim = dictionary['cat_dim']

batch_size = dictionary['batch_size']
epochs = dictionary['epochs']

cluster_number = dictionary['cluster_number']

reconstruction_loss_factor = dictionary['reconstruction_loss_factor']

# %%
input_shape = (original_dim, )
input_shape_r = (1, )

# %% [markdown]
# **Define sampling function**

# %%
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], K.int_shape(z_mean)[1]), mean=0., stddev=1.)
    return z_mean + K.exp(0.5*z_log_sigma) * epsilon

# %% [markdown]
# **Input data**

# %%
X = cf.reshape_data_for_clustering(z500)
y = pr_boxcox_spatial

X_train_1, X_test_1, y_train, y_test = train_test_split(z500.values, y, test_size=0.33)

nt,ny,nx = X_train_1.shape
X_train = np.reshape(X_train_1, [nt, ny*nx], order='F')

nt,ny,nx = X_test_1.shape
X_test = np.reshape(X_test_1, [nt, ny*nx], order='F')

dummy_train = np.ones((X_train.shape[0],1))
dummy_test = np.ones((X_test.shape[0],1))
dummy_full = np.ones((X.shape[0],1))

# %% [markdown]
# ### Define RMM-VAE Model

# %% [markdown]
# **Encoder**

# %%
inputs = Input(shape=input_shape, name='encoder_input')
inputs_r = Input(shape=input_shape_r, name='ground_truth')

inter_x1 = Dense(dim_layer1, activation=activation_function, name='encoder_intermediate')(inputs)
inter_x2 = Dense(dim_layer2, activation=activation_function, name='encoder_intermediate_2')(inter_x1)

dummy = Input(shape=(1,), name='dummy')
mu_vector = Dense(cluster_number*latent_dim, name='mu_vector',use_bias=False)(dummy)
mu = Reshape((cluster_number,latent_dim), name='mu')(mu_vector)

pi = Dense(cluster_number, activation='softmax', name='pi')(dummy)
c = Dense(cluster_number, activation='softmax', name='c')(inter_x2)

z_mean = Dense(latent_dim, name='z_mean')(inter_x2)
z_log_var = Dense(latent_dim, name='z_log_var')(inter_x2)

r_mean = Dense(1, name='r_mean')(inter_x2)
r_log_var = Dense(1, name='r_log_var')(inter_x2)

z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
r = Lambda(sampling, output_shape=(1,), name='r')([r_mean, r_log_var])

pz_mean = Dense(latent_dim, name='pz_mean',kernel_constraint=unit_norm())(r)

encoder = Model([inputs,dummy, inputs_r], [z_mean, z_log_var, z, mu, c, pi, r_mean, r_log_var, r, pz_mean], name='encoder')
encoder.summary()
plot_model(encoder, show_shapes=True, dpi=100)
plot_model(encoder, to_file=filepath+'encoder_graph.png', show_shapes=True, dpi=100)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 286)]        0           []
#
#  encoder_intermediate (Dense)   (None, 128)          36736       ['encoder_input[0][0]']
#
#  encoder_intermediate_2 (Dense)  (None, 64)          8256        ['encoder_intermediate[0][0]']
#
#  dummy (InputLayer)             [(None, 1)]          0           []
#
#  r_mean (Dense)                 (None, 1)            65          ['encoder_intermediate_2[0][0]']
#
#  r_log_var (Dense)              (None, 1)            65          ['encoder_intermediate_2[0][0]']
#
#  z_mean (Dense)                 (None, 10)           650         ['encoder_intermediate_2[0][0]']
#
#  z_log_var (Dense)              (None, 10)           650         ['encoder_intermediate_2[0][0]']
#
#  mu_vector (Dense)              (None, 50)           50          ['dummy[0][0]']
#
#  r (Lambda)                     (None, 1)            0           ['r_mean[0][0]',
#                                                                   'r_log_var[0][0]']
#
#  ground_truth (InputLayer)      [(None, 1)]          0           []
#
#  z (Lambda)                     (None, 10)           0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  mu (Reshape)                   (None, 5, 10)        0           ['mu_vector[0][0]']
#
#  c (Dense)                      (None, 5)            325         ['encoder_intermediate_2[0][0]']
#
#  pi (Dense)                     (None, 5)            10          ['dummy[0][0]']
#
#  pz_mean (Dense)                (None, 10)           20          ['r[0][0]']
#
# ==================================================================================================
# Total params: 46,827
# Trainable params: 46,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-10-12 22:29:13.316248: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# **Decoder**

# %%
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
inter_y1 = Dense(dim_layer2, activation=activation_function)(latent_inputs)
inter_y2 = Dense(dim_layer1, activation=activation_function)(inter_y1)
outputs = Dense(original_dim)(inter_y2)

decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, show_shapes=True, dpi=100)
plot_model(decoder, to_file=filepath+'decoder_graph.png', show_shapes=True, dpi=100)
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 10)]              0
#
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 286)               36894
#
# =================================================================
# Total params: 45,918
# Trainable params: 45,918
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **combine encoder and decoder to VAE model and print summary**

# %%
outputs = decoder(encoder([inputs,dummy, inputs_r])[2])
vae = Model([inputs,dummy, inputs_r], outputs, name='vae_regression')
vae.summary()
# Out:
# Model: "vae_regression"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 286)]        0           []
#
#  dummy (InputLayer)             [(None, 1)]          0           []
#
#  ground_truth (InputLayer)      [(None, 1)]          0           []
#
#  encoder (Functional)           [(None, 10),         46827       ['encoder_input[0][0]',
#                                  (None, 10),                      'dummy[0][0]',
#                                  (None, 10),                      'ground_truth[0][0]']
#                                  (None, 5, 10),
#                                  (None, 5),
#                                  (None, 5),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 10)]
#
#  decoder (Functional)           (None, 286)          45918       ['encoder[0][2]']
#
# ==================================================================================================
# Total params: 92,745
# Trainable params: 92,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Define loss function**

# %%
reconstruction_loss = mse(inputs, outputs)*original_dim*reconstruction_loss_factor

# sum over reconstruction loss and kl-div loss
kl_loss_all = K.tf.compat.v1.get_variable("kl_loss_all", [batch_size,1], 
                                dtype=K.tf.float32,initializer=K.tf.zeros_initializer)
kl_loss_all_2 = K.tf.compat.v1.get_variable("kl_loss_all_2", [batch_size,1], 
                                dtype=K.tf.float32,initializer=K.tf.zeros_initializer)
kl_cat_all = K.tf.compat.v1.get_variable("kl_cat_all", [batch_size,1], 
                                dtype=K.tf.float32,initializer=K.tf.zeros_initializer)
dir_prior_all = K.tf.compat.v1.get_variable("dir_prior_all", [batch_size,1], 
                                  dtype=K.tf.float32,initializer=K.tf.zeros_initializer)
label_loss_all = K.tf.compat.v1.get_variable("label_prior_all", [batch_size,1], 
                                  dtype=K.tf.float32,initializer=K.tf.zeros_initializer)

for i in range(0,cluster_number):
    
    kl_loss = 1 + z_log_var - K.square(z_mean-mu[:,i,:]) - K.exp(z_log_var)
    kl_loss = K.tf.multiply(K.sum(kl_loss, axis=-1), c[:,i])
    kl_loss = -0.5*(kl_loss)
    kl_loss_all = kl_loss_all + kl_loss
    
    kl_loss_2 = 1 + z_log_var - K.square(z_mean-pz_mean) - K.exp(z_log_var)
    kl_loss_2 = K.tf.multiply(K.sum(kl_loss_2, axis=-1), c[:,i])
    kl_loss_2 = -0.5*(kl_loss_2)
    kl_loss_all_2 = kl_loss_all_2 + kl_loss_2
    
    mc = K.mean(c[:,i])
    mpi = K.mean(pi[:,i])
    kl_cat = mc * K.log(mc)- mc * K.log(mpi)
    kl_cat_all = kl_cat_all+kl_cat
    
    dir_prior = -0.1*K.log(pi[:,i])
    dir_prior_all = dir_prior_all + dir_prior
    
    label_loss = K.tf.divide(0.5*K.square(r_mean - inputs_r), K.exp(r_log_var)) +  0.5 * r_log_var
    label_loss = K.tf.multiply(K.sum(label_loss, axis=-1), c[:,i])
    label_loss_all = label_loss_all + label_loss

# %%
vae_loss = K.mean(reconstruction_loss+kl_loss_all+kl_cat_all+label_loss_all+kl_loss_all_2+dir_prior_all)

vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
vae.save_weights(filepath+'random_weights.h5')
# Out:
# Model: "vae_regression"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 286)]        0           []
#
#  dummy (InputLayer)             [(None, 1)]          0           []
#
#  ground_truth (InputLayer)      [(None, 1)]          0           []
#
#  encoder (Functional)           [(None, 10),         46827       ['encoder_input[0][0]',
#                                  (None, 10),                      'dummy[0][0]',
#                                  (None, 10),                      'ground_truth[0][0]']
#                                  (None, 5, 10),
#                                  (None, 5),
#                                  (None, 5),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 10)]
#
#  decoder (Functional)           (None, 286)          45918       ['encoder[0][2]']
#
#  encoder_intermediate (Dense)   (None, 128)          36736       ['encoder_input[0][0]']
#
#  mu_vector (Dense)              (None, 50)           50          ['dummy[0][0]']
#
#  encoder_intermediate_2 (Dense)  (None, 64)          8256        ['encoder_intermediate[0][0]']
#
#  mu (Reshape)                   (None, 5, 10)        0           ['mu_vector[0][0]']
#
#  z_mean (Dense)                 (None, 10)           650         ['encoder_intermediate_2[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 10)          0           ['mu[0][0]']
#  ingOpLambda)
#
#  z_log_var (Dense)              (None, 10)           650         ['encoder_intermediate_2[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 10)           0           ['z_mean[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.__operators__.getitem_7 (Sl  (None, 10)          0           ['mu[0][0]']
#  icingOpLambda)
#
#  r_mean (Dense)                 (None, 1)            65          ['encoder_intermediate_2[0][0]']
#
#  r_log_var (Dense)              (None, 1)            65          ['encoder_intermediate_2[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 10)          0           ['z_log_var[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 10)           0           ['tf.math.subtract[0][0]']
#
#  tf.math.subtract_8 (TFOpLambda  (None, 10)          0           ['z_mean[0][0]',
#  )                                                                'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  tf.__operators__.getitem_14 (S  (None, 10)          0           ['mu[0][0]']
#  licingOpLambda)
#
#  r (Lambda)                     (None, 1)            0           ['r_mean[0][0]',
#                                                                   'r_log_var[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 10)          0           ['tf.__operators__.add[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 10)           0           ['z_log_var[0][0]']
#
#  c (Dense)                      (None, 5)            325         ['encoder_intermediate_2[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 10)          0           ['z_log_var[0][0]']
#  mbda)
#
#  tf.math.square_3 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_8[0][0]']
#
#  tf.math.subtract_16 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'tf.__operators__.getitem_14[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_21 (S  (None, 10)          0           ['mu[0][0]']
#  licingOpLambda)
#
#  pi (Dense)                     (None, 5)            10          ['dummy[0][0]']
#
#  tf.math.subtract_7 (TFOpLambda  (None, 1)           0           ['r_mean[0][0]',
#  )                                                                'ground_truth[0][0]']
#
#  pz_mean (Dense)                (None, 10)           20          ['r[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 10)          0           ['tf.math.subtract_1[0][0]',
#  )                                                                'tf.math.exp[0][0]']
#
#  tf.math.subtract_9 (TFOpLambda  (None, 10)          0           ['tf.__operators__.add_8[0][0]',
#  )                                                                'tf.math.square_3[0][0]']
#
#  tf.math.exp_3 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_6 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_16[0][0]']
#
#  tf.math.subtract_24 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'tf.__operators__.getitem_21[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_28 (S  (None, 10)          0           ['mu[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None,)             0           ['c[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_4 (Sl  (None,)             0           ['pi[0][0]']
#  icingOpLambda)
#
#  tf.math.square_2 (TFOpLambda)  (None, 1)            0           ['tf.math.subtract_7[0][0]']
#
#  tf.math.subtract_15 (TFOpLambd  (None, 1)           0           ['r_mean[0][0]',
#  a)                                                               'ground_truth[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 10)          0           ['z_mean[0][0]',
#  )                                                                'pz_mean[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_2[0][0]']
#  )
#
#  tf.__operators__.getitem_1 (Sl  (None,)             0           ['c[0][0]']
#  icingOpLambda)
#
#  tf.math.subtract_10 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_9[0][0]',
#  a)                                                               'tf.math.exp_3[0][0]']
#
#  tf.math.subtract_17 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_16[0][0]',
#  a)                                                               'tf.math.square_6[0][0]']
#
#  tf.math.exp_6 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_24 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_9 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_24[0][0]']
#
#  tf.math.subtract_32 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'tf.__operators__.getitem_28[0][
#                                                                  0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  ()                  0           ['tf.__operators__.getitem_3[0][0
#  bda)                                                            ]']
#
#  tf.math.reduce_mean_2 (TFOpLam  ()                  0           ['tf.__operators__.getitem_4[0][0
#  bda)                                                            ]']
#
#  tf.__operators__.getitem_10 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.math.multiply_9 (TFOpLambda  (None, 1)           0           ['tf.math.square_2[0][0]']
#  )
#
#  tf.math.exp_2 (TFOpLambda)     (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.square_5 (TFOpLambda)  (None, 1)            0           ['tf.math.subtract_15[0][0]']
#
#  tf.math.subtract_23 (TFOpLambd  (None, 1)           0           ['r_mean[0][0]',
#  a)                                                               'ground_truth[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 10)          0           ['z_log_var[0][0]']
#  mbda)
#
#  tf.math.square_1 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.subtract_11 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'pz_mean[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]',
#  )                                                                'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None,)             0           ['tf.math.subtract_10[0][0]']
#  da)
#
#  tf.__operators__.getitem_8 (Sl  (None,)             0           ['c[0][0]']
#  icingOpLambda)
#
#  tf.math.subtract_18 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_17[0][0]',
#  a)                                                               'tf.math.exp_6[0][0]']
#
#  tf.math.subtract_25 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_24[0][0]',
#  a)                                                               'tf.math.square_9[0][0]']
#
#  tf.math.exp_9 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_12 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_32[0][0]']
#
#  tf.math.log (TFOpLambda)       ()                   0           ['tf.math.reduce_mean_1[0][0]']
#
#  tf.math.log_1 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_2[0][0]']
#
#  tf.math.reduce_mean_3 (TFOpLam  ()                  0           ['tf.__operators__.getitem_10[0][
#  bda)                                                            0]']
#
#  tf.math.reduce_mean_4 (TFOpLam  ()                  0           ['tf.__operators__.getitem_11[0][
#  bda)                                                            0]']
#
#  tf.__operators__.getitem_17 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_18 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.math.truediv (TFOpLambda)   (None, 1)            0           ['tf.math.multiply_9[0][0]',
#                                                                   'tf.math.exp_2[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 1)           0           ['r_log_var[0][0]']
#  a)
#
#  tf.math.multiply_19 (TFOpLambd  (None, 1)           0           ['tf.math.square_5[0][0]']
#  a)
#
#  tf.math.exp_5 (TFOpLambda)     (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.square_8 (TFOpLambda)  (None, 1)            0           ['tf.math.subtract_23[0][0]']
#
#  tf.math.subtract_31 (TFOpLambd  (None, 1)           0           ['r_mean[0][0]',
#  a)                                                               'ground_truth[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 10)          0           ['tf.__operators__.add_2[0][0]',
#  )                                                                'tf.math.square_1[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_4 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_11[0][0]']
#
#  tf.math.subtract_19 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'pz_mean[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None,)             0           ['tf.math.multiply_2[0][0]']
#  )
#
#  tf.math.multiply_12 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_3[0][0]',
#  a)                                                               'tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  tf.math.reduce_sum_6 (TFOpLamb  (None,)             0           ['tf.math.subtract_18[0][0]']
#  da)
#
#  tf.__operators__.getitem_15 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.math.subtract_26 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_25[0][0]',
#  a)                                                               'tf.math.exp_9[0][0]']
#
#  tf.math.subtract_33 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_32[0][0]',
#  a)                                                               'tf.math.square_12[0][0]']
#
#  tf.math.exp_12 (TFOpLambda)    (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  ()                  0           ['tf.math.reduce_mean_1[0][0]',
#  )                                                                'tf.math.log[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  ()                  0           ['tf.math.reduce_mean_1[0][0]',
#  )                                                                'tf.math.log_1[0][0]']
#
#  tf.math.log_3 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_3[0][0]']
#
#  tf.math.log_4 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_4[0][0]']
#
#  tf.math.reduce_mean_5 (TFOpLam  ()                  0           ['tf.__operators__.getitem_17[0][
#  bda)                                                            0]']
#
#  tf.math.reduce_mean_6 (TFOpLam  ()                  0           ['tf.__operators__.getitem_18[0][
#  bda)                                                            0]']
#
#  tf.__operators__.getitem_24 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 1)           0           ['tf.math.truediv[0][0]',
#  mbda)                                                            'tf.math.multiply_10[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 1)           0           ['tf.math.multiply_19[0][0]',
#                                                                   'tf.math.exp_5[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, 1)           0           ['r_log_var[0][0]']
#  a)
#
#  tf.math.multiply_29 (TFOpLambd  (None, 1)           0           ['tf.math.square_8[0][0]']
#  a)
#
#  tf.math.exp_8 (TFOpLambda)     (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.square_11 (TFOpLambda)  (None, 1)           0           ['tf.math.subtract_31[0][0]']
#
#  tf.math.subtract_39 (TFOpLambd  (None, 1)           0           ['r_mean[0][0]',
#  a)                                                               'ground_truth[0][0]']
#
#  tf.math.subtract_5 (TFOpLambda  (None, 10)          0           ['tf.math.subtract_4[0][0]',
#  )                                                                'tf.math.exp_1[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_10[0][0]',
#  a)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.exp_4 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_7 (TFOpLambda)  (None, 10)           0           ['tf.math.subtract_19[0][0]']
#
#  tf.math.subtract_27 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'pz_mean[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (None, 286)         0           ['decoder[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None, 286)          0           ['encoder_input[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (128, None)         0           ['tf.math.multiply_3[0][0]']
#  mbda)
#
#  tf.math.multiply_13 (TFOpLambd  (None,)             0           ['tf.math.multiply_12[0][0]']
#  a)
#
#  tf.math.multiply_22 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_6[0][0]',
#  a)                                                               'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  tf.math.reduce_sum_9 (TFOpLamb  (None,)             0           ['tf.math.subtract_26[0][0]']
#  da)
#
#  tf.__operators__.getitem_22 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.math.subtract_34 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_33[0][0]',
#  a)                                                               'tf.math.exp_12[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  ()                  0           ['tf.math.multiply_6[0][0]',
#  )                                                                'tf.math.multiply_7[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_3[0][0]',
#  a)                                                               'tf.math.log_3[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_3[0][0]',
#  a)                                                               'tf.math.log_4[0][0]']
#
#  tf.math.log_6 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_5[0][0]']
#
#  tf.math.log_7 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_6[0][0]']
#
#  tf.math.reduce_mean_7 (TFOpLam  ()                  0           ['tf.__operators__.getitem_24[0][
#  bda)                                                            0]']
#
#  tf.math.reduce_mean_8 (TFOpLam  ()                  0           ['tf.__operators__.getitem_25[0][
#  bda)                                                            0]']
#
#  tf.__operators__.getitem_31 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_32 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None,)             0           ['tf.__operators__.add_6[0][0]']
#  da)
#
#  tf.__operators__.getitem_6 (Sl  (None,)             0           ['c[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.add_14 (TFOpL  (None, 1)           0           ['tf.math.truediv_1[0][0]',
#  ambda)                                                           'tf.math.multiply_20[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 1)           0           ['tf.math.multiply_29[0][0]',
#                                                                   'tf.math.exp_8[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 1)           0           ['r_log_var[0][0]']
#  a)
#
#  tf.math.multiply_39 (TFOpLambd  (None, 1)           0           ['tf.math.square_11[0][0]']
#  a)
#
#  tf.math.exp_11 (TFOpLambda)    (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.square_14 (TFOpLambda)  (None, 1)           0           ['tf.math.subtract_39[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None,)             0           ['tf.math.subtract_5[0][0]']
#  da)
#
#  tf.__operators__.getitem_2 (Sl  (None,)             0           ['c[0][0]']
#  icingOpLambda)
#
#  tf.math.subtract_13 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_12[0][0]',
#  a)                                                               'tf.math.exp_4[0][0]']
#
#  tf.math.subtract_20 (TFOpLambd  (None, 10)          0           ['tf.__operators__.add_18[0][0]',
#  a)                                                               'tf.math.square_7[0][0]']
#
#  tf.math.exp_7 (TFOpLambda)     (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 10)          0           ['z_log_var[0][0]']
#  ambda)
#
#  tf.math.square_10 (TFOpLambda)  (None, 10)          0           ['tf.math.subtract_27[0][0]']
#
#  tf.math.subtract_35 (TFOpLambd  (None, 10)          0           ['z_mean[0][0]',
#  a)                                                               'pz_mean[0][0]']
#  tf.math.squared_difference (TF  (None, 286)         0           ['tf.convert_to_tensor[0][0]',
#  OpLambda)                                                        'tf.cast[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (128, None)         0           ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'tf.math.multiply_13[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None,)             0           ['tf.math.multiply_22[0][0]']
#  a)
#
#  tf.math.multiply_32 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_9[0][0]',
#  a)                                                               'tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  tf.math.reduce_sum_12 (TFOpLam  (None,)             0           ['tf.math.subtract_34[0][0]']
#  bda)
#
#  tf.__operators__.getitem_29 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_4 (TFOpLa  (128, 1)            0           ['tf.math.subtract_6[0][0]']
#  mbda)
#
#  tf.math.subtract_14 (TFOpLambd  ()                  0           ['tf.math.multiply_16[0][0]',
#  a)                                                               'tf.math.multiply_17[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_5[0][0]',
#  a)                                                               'tf.math.log_6[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_5[0][0]',
#  a)                                                               'tf.math.log_7[0][0]']
#
#  tf.math.log_9 (TFOpLambda)     ()                   0           ['tf.math.reduce_mean_7[0][0]']
#
#  tf.math.log_10 (TFOpLambda)    ()                   0           ['tf.math.reduce_mean_8[0][0]']
#
#  tf.math.reduce_mean_9 (TFOpLam  ()                  0           ['tf.__operators__.getitem_31[0][
#  bda)                                                            0]']
#
#  tf.math.reduce_mean_10 (TFOpLa  ()                  0           ['tf.__operators__.getitem_32[0][
#  mbda)                                                           0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_2[0][0]',
#  a)                                                               'tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  tf.math.reduce_sum_5 (TFOpLamb  (None,)             0           ['tf.__operators__.add_14[0][0]']
#  da)
#
#  tf.__operators__.getitem_13 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_22 (TFOpL  (None, 1)           0           ['tf.math.truediv_2[0][0]',
#  ambda)                                                           'tf.math.multiply_30[0][0]']
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 1)           0           ['tf.math.multiply_39[0][0]',
#                                                                   'tf.math.exp_11[0][0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 1)           0           ['r_log_var[0][0]']
#  a)
#
#  tf.math.multiply_49 (TFOpLambd  (None, 1)           0           ['tf.math.square_14[0][0]']
#  a)
#
#  tf.math.exp_14 (TFOpLambda)    (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum_1[0][0]',
#  )                                                                'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (None,)             0           ['tf.math.subtract_13[0][0]']
#  da)
#
# ...
#  a)
#
#  tf.math.multiply_24 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]',
#  a)                                                               'tf.__operators__.getitem_16[0][
#                                                                  0]']
#
#  tf.math.reduce_sum_10 (TFOpLam  (None,)             0           ['tf.math.subtract_29[0][0]']
#  bda)
#
#  tf.__operators__.getitem_23 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.math.subtract_37 (TFOpLambd  (None, 10)          0           ['tf.math.subtract_36[0][0]',
#  a)                                                               'tf.math.exp_13[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None,)             0           ['tf.math.log_2[0][0]']
#  )
#
#  tf.math.log_5 (TFOpLambda)     (None,)              0           ['tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_19 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.__operators__.add_33 (TFOpL  (128, None)         0           ['tf.__operators__.add_25[0][0]',
#  ambda)                                                           'tf.math.multiply_43[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (128, 1)            0           ['tf.__operators__.add_20[0][0]',
#  ambda)                                                           'tf.math.subtract_30[0][0]']
#
#  tf.math.subtract_38 (TFOpLambd  ()                  0           ['tf.math.multiply_46[0][0]',
#  a)                                                               'tf.math.multiply_47[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (128, None)         0           ['tf.__operators__.add_15[0][0]',
#  ambda)                                                           'tf.math.multiply_31[0][0]']
#
#  tf.math.multiply_41 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_11[0][0]',
#  a)                                                               'tf.__operators__.getitem_27[0][
#                                                                  0]']
#
#  tf.math.reduce_sum_14 (TFOpLam  (None,)             0           ['tf.__operators__.add_38[0][0]']
#  bda)
#
#  tf.__operators__.getitem_34 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_11 (TFOpL  (128, None)         0           ['tf.__operators__.add_3[0][0]',
#  ambda)                                                           'tf.math.multiply_15[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None,)             0           ['tf.math.multiply_24[0][0]']
#  a)
#
#  tf.math.multiply_34 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_10[0][0]',
#  a)                                                               'tf.__operators__.getitem_23[0][
#                                                                  0]']
#
#  tf.math.reduce_sum_13 (TFOpLam  (None,)             0           ['tf.math.subtract_37[0][0]']
#  bda)
#
#  tf.__operators__.getitem_30 (S  (None,)             0           ['c[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_5 (TFOpLa  (128, None)         0           ['tf.math.multiply_8[0][0]']
#  mbda)
#
#  tf.math.multiply_18 (TFOpLambd  (None,)             0           ['tf.math.log_5[0][0]']
#  a)
#
#  tf.math.log_8 (TFOpLambda)     (None,)              0           ['tf.__operators__.getitem_19[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_26 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_40 (TFOpL  (128, None)         0           ['tf.math.multiply_1[0][0]',
#  ambda)                                                           'tf.__operators__.add_33[0][0]']
#
#  tf.__operators__.add_36 (TFOpL  (128, 1)            0           ['tf.__operators__.add_28[0][0]',
#  ambda)                                                           'tf.math.subtract_38[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (128, None)         0           ['tf.__operators__.add_23[0][0]',
#  ambda)                                                           'tf.math.multiply_41[0][0]']
#
#  tf.math.multiply_51 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_14[0][0]',
#  a)                                                               'tf.__operators__.getitem_34[0][
#                                                                  0]']
#
#  tf.__operators__.add_19 (TFOpL  (128, None)         0           ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'tf.math.multiply_25[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None,)             0           ['tf.math.multiply_34[0][0]']
#  a)
#
#  tf.math.multiply_44 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_13[0][0]',
#  a)                                                               'tf.__operators__.getitem_30[0][
#                                                                  0]']
#
#  tf.__operators__.add_13 (TFOpL  (128, None)         0           ['tf.__operators__.add_5[0][0]',
#  ambda)                                                           'tf.math.multiply_18[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None,)             0           ['tf.math.log_8[0][0]']
#  a)
#
#  tf.math.log_11 (TFOpLambda)    (None,)              0           ['tf.__operators__.getitem_26[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_33 (S  (None,)             0           ['pi[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.add_41 (TFOpL  (128, None)         0           ['tf.__operators__.add_40[0][0]',
#  ambda)                                                           'tf.__operators__.add_36[0][0]']
#
#  tf.__operators__.add_39 (TFOpL  (128, None)         0           ['tf.__operators__.add_31[0][0]',
#  ambda)                                                           'tf.math.multiply_51[0][0]']
#
#  tf.__operators__.add_27 (TFOpL  (128, None)         0           ['tf.__operators__.add_19[0][0]',
#  ambda)                                                           'tf.math.multiply_35[0][0]']
#
#  tf.math.multiply_45 (TFOpLambd  (None,)             0           ['tf.math.multiply_44[0][0]']
#  a)
#
#  tf.__operators__.add_21 (TFOpL  (128, None)         0           ['tf.__operators__.add_13[0][0]',
#  ambda)                                                           'tf.math.multiply_28[0][0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None,)             0           ['tf.math.log_11[0][0]']
#  a)
#
#  tf.math.log_14 (TFOpLambda)    (None,)              0           ['tf.__operators__.getitem_33[0][
#                                                                  0]']
#
#  tf.__operators__.add_42 (TFOpL  (128, None)         0           ['tf.__operators__.add_41[0][0]',
#  ambda)                                                           'tf.__operators__.add_39[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (128, None)         0           ['tf.__operators__.add_27[0][0]',
#  ambda)                                                           'tf.math.multiply_45[0][0]']
#
#  tf.__operators__.add_29 (TFOpL  (128, None)         0           ['tf.__operators__.add_21[0][0]',
#  ambda)                                                           'tf.math.multiply_38[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None,)             0           ['tf.math.log_14[0][0]']
#  a)
#
#  tf.__operators__.add_43 (TFOpL  (128, None)         0           ['tf.__operators__.add_42[0][0]',
#  ambda)                                                           'tf.__operators__.add_35[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (128, None)         0           ['tf.__operators__.add_29[0][0]',
#  ambda)                                                           'tf.math.multiply_48[0][0]']
#
#  tf.__operators__.add_44 (TFOpL  (128, None)         0           ['tf.__operators__.add_43[0][0]',
#  ambda)                                                           'tf.__operators__.add_37[0][0]']
#
#  tf.math.reduce_mean_11 (TFOpLa  ()                  0           ['tf.__operators__.add_44[0][0]']
#  mbda)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean_11[0][0]']
#
# ==================================================================================================
# Total params: 92,745
# Trainable params: 92,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Evaluate convergence of loss function on test-train data split**

# %%
history = vae.fit([X_train,dummy_train, y_train], [X_train,dummy_train, y_train], epochs=epochs, 
                  batch_size=batch_size, 
                  validation_data=([X_test,dummy_test,y_test], [X_test,dummy_test,y_test]))
# Out:
# Epoch 1/100
# 66/66 [==============================] - 5s 16ms/step - loss: 155.0789 - val_loss: 89.8511
# Epoch 2/100
# 66/66 [==============================] - 0s 7ms/step - loss: 80.4324 - val_loss: 69.2963
# Epoch 3/100
# 66/66 [==============================] - 0s 7ms/step - loss: 61.6513 - val_loss: 56.6432
# Epoch 4/100
# 66/66 [==============================] - 0s 6ms/step - loss: 54.3364 - val_loss: 52.8784
# Epoch 5/100
# 66/66 [==============================] - 0s 6ms/step - loss: 51.4212 - val_loss: 50.0953
# Epoch 6/100
# 66/66 [==============================] - 0s 6ms/step - loss: 49.5149 - val_loss: 48.4985
# Epoch 7/100
# 66/66 [==============================] - 0s 6ms/step - loss: 47.7984 - val_loss: 46.7752
# Epoch 8/100
# 66/66 [==============================] - 0s 6ms/step - loss: 46.5796 - val_loss: 45.9974
# Epoch 9/100
# 66/66 [==============================] - 0s 6ms/step - loss: 45.6573 - val_loss: 45.3724
# Epoch 10/100
# 66/66 [==============================] - 0s 6ms/step - loss: 45.1330 - val_loss: 44.9334
# Epoch 11/100
# 66/66 [==============================] - 0s 6ms/step - loss: 44.5685 - val_loss: 44.3938
# Epoch 12/100
# 66/66 [==============================] - 0s 6ms/step - loss: 44.1907 - val_loss: 43.7429
# Epoch 13/100
# 66/66 [==============================] - 0s 6ms/step - loss: 43.7385 - val_loss: 43.3729
# Epoch 14/100
# 66/66 [==============================] - 0s 6ms/step - loss: 43.3560 - val_loss: 43.4336
# Epoch 15/100
# 66/66 [==============================] - 0s 6ms/step - loss: 42.9598 - val_loss: 43.0524
# Epoch 16/100
# 66/66 [==============================] - 0s 6ms/step - loss: 42.9852 - val_loss: 43.4020
# Epoch 17/100
# 66/66 [==============================] - 0s 6ms/step - loss: 42.7212 - val_loss: 42.8809
# Epoch 18/100
# 66/66 [==============================] - 0s 6ms/step - loss: 42.2455 - val_loss: 42.3204
# Epoch 19/100
# 66/66 [==============================] - 0s 6ms/step - loss: 42.0758 - val_loss: 42.3048
# Epoch 20/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.9483 - val_loss: 42.1153
# Epoch 21/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.8354 - val_loss: 41.6987
# Epoch 22/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.5066 - val_loss: 41.3930
# Epoch 23/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.6113 - val_loss: 41.5465
# Epoch 24/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.3749 - val_loss: 41.4361
# Epoch 25/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.2748 - val_loss: 41.4931
# Epoch 26/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.2309 - val_loss: 41.1946
# Epoch 27/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.1182 - val_loss: 41.3488
# Epoch 28/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.1133 - val_loss: 41.1478
# Epoch 29/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.1869 - val_loss: 41.4547
# Epoch 30/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.9391 - val_loss: 41.1644
# Epoch 31/100
# 66/66 [==============================] - 0s 6ms/step - loss: 41.1404 - val_loss: 40.8670
# Epoch 32/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.8715 - val_loss: 41.0096
# Epoch 33/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.8009 - val_loss: 40.7106
# Epoch 34/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.7547 - val_loss: 40.8624
# Epoch 35/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.7392 - val_loss: 40.8282
# Epoch 36/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.6882 - val_loss: 40.9545
# Epoch 37/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.7929 - val_loss: 40.5985
# Epoch 38/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.6851 - val_loss: 40.8461
# Epoch 39/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.7691 - val_loss: 40.6614
# Epoch 40/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.6895 - val_loss: 40.5829
# Epoch 41/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.7360 - val_loss: 40.8511
# Epoch 42/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.5057 - val_loss: 40.8144
# Epoch 43/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.5347 - val_loss: 40.5508
# Epoch 44/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.4764 - val_loss: 40.7727
# Epoch 45/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.4238 - val_loss: 40.5918
# Epoch 46/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.4110 - val_loss: 40.4172
# Epoch 47/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.3587 - val_loss: 40.4067
# Epoch 48/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.4177 - val_loss: 40.1755
# Epoch 49/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.4252 - val_loss: 40.3278
# Epoch 50/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.3695 - val_loss: 40.5485
# Epoch 51/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.3191 - val_loss: 40.2322
# Epoch 52/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2299 - val_loss: 40.3759
# Epoch 53/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2993 - val_loss: 40.4625
# Epoch 54/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2100 - val_loss: 40.3827
# Epoch 55/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2524 - val_loss: 40.0995
# Epoch 56/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0125 - val_loss: 40.3808
# Epoch 57/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0833 - val_loss: 40.5961
# Epoch 58/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2909 - val_loss: 40.2494
# Epoch 59/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2952 - val_loss: 40.1402
# Epoch 60/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2627 - val_loss: 40.0043
# Epoch 61/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.2659 - val_loss: 40.5028
# Epoch 62/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0463 - val_loss: 40.1632
# Epoch 63/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9962 - val_loss: 40.0916
# Epoch 64/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0253 - val_loss: 39.9286
# Epoch 65/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9822 - val_loss: 40.3253
# Epoch 66/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0074 - val_loss: 40.2746
# Epoch 67/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9634 - val_loss: 40.2552
# Epoch 68/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8272 - val_loss: 39.8653
# Epoch 69/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0296 - val_loss: 40.1023
# Epoch 70/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8575 - val_loss: 39.9653
# Epoch 71/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9835 - val_loss: 39.6942
# Epoch 72/100
# 66/66 [==============================] - 0s 6ms/step - loss: 40.0099 - val_loss: 40.2450
# Epoch 73/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9538 - val_loss: 40.3705
# Epoch 74/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9340 - val_loss: 39.8123
# Epoch 75/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9297 - val_loss: 39.8927
# Epoch 76/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9224 - val_loss: 40.0186
# Epoch 77/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8624 - val_loss: 39.9557
# Epoch 78/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9569 - val_loss: 40.0852
# Epoch 79/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9493 - val_loss: 39.8698
# Epoch 80/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7354 - val_loss: 40.2839
# Epoch 81/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7495 - val_loss: 40.0678
# Epoch 82/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9189 - val_loss: 39.9188
# Epoch 83/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8228 - val_loss: 39.9715
# Epoch 84/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7627 - val_loss: 39.8207
# Epoch 85/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.6959 - val_loss: 39.6904
# Epoch 86/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.9192 - val_loss: 40.0482
# Epoch 87/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8034 - val_loss: 40.1769
# Epoch 88/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7927 - val_loss: 39.8228
# Epoch 89/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8326 - val_loss: 40.0434
# Epoch 90/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7738 - val_loss: 40.0673
# Epoch 91/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7107 - val_loss: 39.7164
# Epoch 92/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7792 - val_loss: 39.8593
# Epoch 93/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7301 - val_loss: 39.8738
# Epoch 94/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.5640 - val_loss: 39.9054
# Epoch 95/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.8065 - val_loss: 39.9096
# Epoch 96/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.6798 - val_loss: 39.9853
# Epoch 97/100
# 66/66 [==============================] - 0s 7ms/step - loss: 39.7028 - val_loss: 39.7294
# Epoch 98/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.4986 - val_loss: 39.9520
# Epoch 99/100
# 66/66 [==============================] - 1s 9ms/step - loss: 39.7449 - val_loss: 40.0306
# Epoch 100/100
# 66/66 [==============================] - 0s 6ms/step - loss: 39.7065 - val_loss: 39.9101

# %%
fig, ax = plt.subplots(figsize=(16,9), dpi=300)
plt.title(label='Model Loss by Epoch', loc='center')

ax.plot(history.history['loss'], label='Training Data', color='black')
ax.plot(history.history['val_loss'], label='Test Data', color='red')
ax.set(xlabel='Epoch', ylabel='Loss')
plt.xticks(ticks=np.arange(len(history.history['loss']), step=1), labels=np.arange(1, len(history.history['loss'])+1, step=1))
plt.legend()
plt.show()
fig.savefig(filepath+'loss_function.png')

# %% [markdown]
# **Load random weights and train on entire dataset**

# %%
vae.load_weights(filepath+'random_weights.h5')
vae.fit([X,dummy_full, y], epochs=epochs, 
                  batch_size=batch_size, 
                  verbose=1)
 
[z_mean, z_log_var, z, mu, c, pi, r_mean, r_log_var, r, pz_mean] = encoder.predict([X,dummy_full, y],batch_size=batch_size)
# Out:
# Epoch 1/100
# 99/99 [==============================] - 3s 4ms/step - loss: 126.8021
# Epoch 2/100
# 99/99 [==============================] - 0s 4ms/step - loss: 63.8746
# Epoch 3/100
# 99/99 [==============================] - 0s 4ms/step - loss: 53.9638
# Epoch 4/100
# 99/99 [==============================] - 0s 5ms/step - loss: 50.6341
# Epoch 5/100
# 99/99 [==============================] - 0s 5ms/step - loss: 48.0654
# Epoch 6/100
# 99/99 [==============================] - 0s 5ms/step - loss: 46.2499
# Epoch 7/100
# 99/99 [==============================] - 0s 5ms/step - loss: 45.2079
# Epoch 8/100
# 99/99 [==============================] - 0s 4ms/step - loss: 44.5189
# Epoch 9/100
# 99/99 [==============================] - 0s 4ms/step - loss: 43.9292
# Epoch 10/100
# 99/99 [==============================] - 0s 4ms/step - loss: 43.5019
# Epoch 11/100
# 99/99 [==============================] - 0s 4ms/step - loss: 42.9926
# Epoch 12/100
# 99/99 [==============================] - 0s 4ms/step - loss: 42.5525
# Epoch 13/100
# 99/99 [==============================] - 0s 4ms/step - loss: 42.3469
# Epoch 14/100
# 99/99 [==============================] - 0s 4ms/step - loss: 42.0227
# Epoch 15/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.7831
# Epoch 16/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.6926
# Epoch 17/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.5950
# Epoch 18/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.3370
# Epoch 19/100
# 99/99 [==============================] - 0s 5ms/step - loss: 41.3166
# Epoch 20/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.1410
# Epoch 21/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.1055
# Epoch 22/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.0719
# Epoch 23/100
# 99/99 [==============================] - 0s 4ms/step - loss: 41.1076
# Epoch 24/100
# 99/99 [==============================] - 1s 6ms/step - loss: 40.9299
# Epoch 25/100
# 99/99 [==============================] - 1s 6ms/step - loss: 40.7417
# Epoch 26/100
# 99/99 [==============================] - 1s 6ms/step - loss: 40.7494
# Epoch 27/100
# 99/99 [==============================] - 1s 6ms/step - loss: 40.6790
# Epoch 28/100
# 99/99 [==============================] - 1s 6ms/step - loss: 40.5386
# Epoch 29/100
# 99/99 [==============================] - 1s 5ms/step - loss: 40.5506
# Epoch 30/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.5763
# Epoch 31/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.5408
# Epoch 32/100
# 99/99 [==============================] - 0s 5ms/step - loss: 40.3869
# Epoch 33/100
# 99/99 [==============================] - 0s 5ms/step - loss: 40.4995
# Epoch 34/100
# 99/99 [==============================] - 0s 5ms/step - loss: 40.2950
# Epoch 35/100
# 99/99 [==============================] - 0s 5ms/step - loss: 40.2869
# Epoch 36/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.3964
# Epoch 37/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.2367
# Epoch 38/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.2361
# Epoch 39/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.0369
# Epoch 40/100
# 99/99 [==============================] - 0s 5ms/step - loss: 40.0261
# Epoch 41/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.1192
# Epoch 42/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.1527
# Epoch 43/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.1365
# Epoch 44/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.9471
# Epoch 45/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.9370
# Epoch 46/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.9439
# Epoch 47/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.0802
# Epoch 48/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.0131
# Epoch 49/100
# 99/99 [==============================] - 0s 4ms/step - loss: 40.0462
# Epoch 50/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.9755
# Epoch 51/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.8266
# Epoch 52/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.8754
# Epoch 53/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7890
# Epoch 54/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.8870
# Epoch 55/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7589
# Epoch 56/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7982
# Epoch 57/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7951
# Epoch 58/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7157
# Epoch 59/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7445
# Epoch 60/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7302
# Epoch 61/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.7596
# Epoch 62/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.7012
# Epoch 63/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.6058
# Epoch 64/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.6478
# Epoch 65/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.7331
# Epoch 66/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.6633
# Epoch 67/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6146
# Epoch 68/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5265
# Epoch 69/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6460
# Epoch 70/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7163
# Epoch 71/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5557
# Epoch 72/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.7902
# Epoch 73/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6806
# Epoch 74/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.6649
# Epoch 75/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6357
# Epoch 76/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6630
# Epoch 77/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6099
# Epoch 78/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5135
# Epoch 79/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6374
# Epoch 80/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5528
# Epoch 81/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.4414
# Epoch 82/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.6173
# Epoch 83/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5713
# Epoch 84/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.5749
# Epoch 85/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.5139
# Epoch 86/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.5263
# Epoch 87/100
# 99/99 [==============================] - 1s 5ms/step - loss: 39.6389
# Epoch 88/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.4851
# Epoch 89/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.3750
# Epoch 90/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.5027
# Epoch 91/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3667
# Epoch 92/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3594
# Epoch 93/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.4174
# Epoch 94/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3890
# Epoch 95/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.4004
# Epoch 96/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.4576
# Epoch 97/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3731
# Epoch 98/100
# 99/99 [==============================] - 0s 5ms/step - loss: 39.4570
# Epoch 99/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3425
# Epoch 100/100
# 99/99 [==============================] - 0s 4ms/step - loss: 39.3053
# 99/99 [==============================] - 0s 2ms/step

# %% [markdown]
# **Apply trained model**

# %%
X_decoded = decoder.predict(z)
# Out:
# 393/393 [==============================] - 0s 859us/step

# %% [markdown]
# **Reconstruct flattened data to xarray lat-lon**

# %%
reconstructed = X_decoded.reshape(X_decoded.shape[0], inputdim2, inputdim1)
reconstructed = np.transpose(reconstructed, (0, 2, 1))
reconstructed_xr = xr.DataArray(reconstructed, coords=z500[0:X_decoded.shape[0], :, :].coords, 
                         dims=z500[0:X_decoded.shape[0], :, :].dims, attrs=z500[0:X_decoded.shape[0], :, :].attrs)

# %% [markdown]
# **save cluster probabilities and post likely labels, relabel data based on precipitation amount**

# %%
labels = np.zeros(X.shape[0])
for i in range(0, X.shape[0]):
    max_prob = np.max(c[i,:])
    idx = np.argmax(c[i,:])
    labels[i] = idx

df = pd.DataFrame(data=c)
df['label'] = labels
df.to_csv(filepath+'cluster_probabilities_'+str(cluster_number)+'.csv')

# %%
pr_labeled = cf.assign_labels(xarray_array=pr, labels=labels)
pr_by_label = pr_labeled.groupby('label').mean(dim=['time', 'latitude', 'longitude'])
cluster_order = np.flip(np.argsort(pr_by_label.values)).tolist()

dict_replace = {0: cluster_order.index(0), 1: cluster_order.index(1), 2: cluster_order.index(2), 
                3: cluster_order.index(3), 4:cluster_order.index(4)}

def replace(element):
    return dict_replace.get(element, element)

vfunc = np.vectorize(replace)

relabeled_labels = vfunc(labels)

d = {'Labels': 'RMM-VAE', 'Value': relabeled_labels}
df = pd.DataFrame(data=d)
df.to_csv(filepath+'relabeled_labels.csv')

# %% [markdown]
# **t-sne visualisation**

# %%
tsne = TSNE(n_components=2, random_state=0, perplexity=10)
X_2d = tsne.fit_transform(z)

# %%
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=relabeled_labels, s=7)
plt.title('Latent Space Representation Basic VAE + original kmeans clusters')
#plt.legend(*scatter.legend_elements())
plt.savefig(filepath+'tsne_kmeans_'+str(cluster_number)+'.png')

# %%
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=pr_spatial.values, cmap='GnBu', s=3, alpha=1)
plt.title('Latent Space Representation - precipitation')
#plt.legend(*scatter.legend_elements(), loc='upper left')
plt.savefig(filepath+'tsne_precipitation_'+str(cluster_number)+'_nolegend.png')

# %% [markdown]
# **visualise cluster centers and precipitation odds ratios**

# %%
def visualise_contourplot_labels(cluster_centers, unit, regime_names, vmin, vmax, steps, color_scheme, 
                                   labels_data, labels, col_number=8, borders=True, projection = ccrs.Orthographic(0,45)):
    
    nt,ny,nx = cluster_centers.values.shape
    x,y = np.meshgrid(cluster_centers.longitude, cluster_centers.latitude)
    
    proj = projection
    fig, axes = plt.subplots(1,col_number, figsize=(14, 7), subplot_kw=dict(projection=proj))

    regimes = regime_names

    for i in range(nt):
        
        cluster=cluster_order[i]
        cs = axes.flat[i].contourf(x, y, cluster_centers[cluster, :, :],
                                   levels=np.arange(vmin, vmax, steps), 
                                   transform=ccrs.PlateCarree(),
                                   cmap=color_scheme)
        axes.flat[i].coastlines()
        
        if borders==True:
            axes.flat[i].add_feature(cartopy.feature.BORDERS)
            
        title = '{}, {:4.1f}%'.format(regimes[i], 100*labels_data[labels==cluster, :].shape[0]/labels_data.shape[0])
        axes.flat[i].set_title(title, fontsize=16)
    plt.tight_layout()
    
    return(fig)

# %%
cluster_means_list = []

for i in range(cluster_number):
    reshaped = np.reshape(np.mean(X[labels == i,:],axis=0),[inputdim2,inputdim1])
    reshaped = np.transpose(reshaped, (1, 0))
    cluster_means_list.append(reshaped)
    
cluster_means = np.stack(cluster_means_list)

cluster_centers_xr = xr.DataArray(cluster_means, coords=z500[0:cluster_number, :, :].coords, 
                         dims=z500[0:cluster_number, :, :].dims, attrs=z500[0:cluster_number, :, :].attrs)

cluster_centers_vis = visualise_contourplot_labels(cluster_centers = cluster_centers_xr, unit = '[m]', 
                                            regime_names = ['Regime 1', 'Regime 2', 'Regime 3',
                                                                         'Regime 4', 'Regime 5', 'Regime 6',
                                                                         'Regime 7', 'Regime 8'], 
                                             vmin=-1.7, vmax=1.7, steps=0.2, 
                                             color_scheme = 'RdBu_r', 
                                                      labels_data = X, labels=labels,
                                                      borders=False, col_number=5, projection = ccrs.PlateCarree(central_longitude=0))

plt.savefig(filepath+'cluster_centers.png')

# %%
pr_qn95_ratio = calculate_conditional_probability_change_label(threshold_matrix = threshold_qn95, 
                                                        labels=labels,
                                                       comparison = 'ratio', shift_value=0)

pr_qn95_vis = cf.visualise_spatial_oddsratio(dataset_xarray = pr_qn95_ratio, unit='',
                                             cluster_order=cluster_order,
                                   color_scheme = 'GnBu', vmin = 0, vmax=6, steps=7, 
                                   title = 'Odds ratio of 95th percentile precipitation',
                                             regime_names = ['Regime 1', 'Regime 2', 'Regime 3',
                                                                         'Regime 4', 'Regime 5', 'Regime 6',
                                                                         'Regime 7', 'Regime 8'],
                                   borders=True, projection=ccrs.PlateCarree(central_longitude=0), col_number=5)

plt.savefig(filepath+'oddsratio.png')

# %%
# calculate MSE
mse = mean_squared_error(X_decoded, z500_reshaped, multioutput='raw_values')
d = {'MSE': 'VAE_Regression', 'Value': mse}
df = pd.DataFrame(data=d)
df.to_csv(filepath+'mse.csv')
