# %%
import os
os.chdir('/Users/fionaspuler/Documents/GitHub/RMM-VAE/')

import sys
sys.path[0]='/Users/fionaspuler/Documents/GitHub/RMM-VAE/'

# %%
from keras.models import Model
from keras.layers import Lambda, Input, Dense, Dropout
from keras.constraints import unit_norm
from keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.losses import mse, binary_crossentropy

import pandas as pd
import numpy as np
import xarray as xr

from math import ceil
from scipy import stats

import matplotlib
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.manifold import MDS, TSNE
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

import clustering_functions as cf
import xesmf as xe
# Out:
# 2023-10-12 20:31:34.336308: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
execfile('pre_processing.py')
# Out:
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_morestats.py:933: RuntimeWarning: overflow encountered in power
#   variance = np.var(data**lmb / lmb, axis=0)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:213: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py:2417: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:236: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)

# %% [markdown]
# **import model specifications saved in yaml file**

# %%
import yaml
from yaml import CLoader as Loader
stream = open("model_specifications/R-VAE/v2.yaml", 'r')
dictionary = yaml.load(stream, Loader=Loader)

filepath = dictionary['filepath']

original_dim = dictionary['original_dim']
inputdim1 = dictionary['inputdim1']
inputdim2 = dictionary['inputdim2']

latent_dim = dictionary['latent_dim']
activation_function = dictionary['activation_function']

dim_layer1 = dictionary['dim_layer1']
dim_layer2 = dictionary['dim_layer2']
dim_layer3 = dictionary['dim_layer3']

batch_size = dictionary['batch_size']
epochs = dictionary['epochs']

reconstruction_loss_factor = dictionary['reconstruction_loss_factor']

# %%
input_shape_x = (original_dim, )
input_shape_r = (1, )

# %% [markdown]
# **Define sampling function**

# %%
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], K.int_shape(z_mean)[1]), mean=0., stddev=1.)
    return z_mean + K.exp(0.5*z_log_sigma) * epsilon

# %% [markdown]
# ### Define R-VAE model

# %% [markdown]
# **Encoder**

# %%
inputs_r = Input(shape=input_shape_r, name='ground_truth')
inputs_x = Input(shape=input_shape_x, name='encoder_input')

inter_x1 = Dense(dim_layer1, activation=activation_function, name='encoder_intermediate')(inputs_x)
inter_x2 = Dense(dim_layer2, activation=activation_function, name='encoder_intermediate_2')(inter_x1)
inter_x3 = Dense(dim_layer3, activation=activation_function, name='encoder_intermediate_3')(inter_x2)

r_mean = Dense(1, name='r_mean')(inter_x3)
r_log_var = Dense(1, name='r_log_var')(inter_x3)

z_mean = Dense(latent_dim, name='z_mean')(inter_x3)
z_log_var = Dense(latent_dim, name='z_log_var')(inter_x3)

# reparameterization trick
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
r = Lambda(sampling, output_shape=(1,), name='r')([r_mean, r_log_var])

pz_mean = Dense(latent_dim, name='pz_mean',kernel_constraint=unit_norm())(r)

# encoder model
encoder = Model([inputs_x,inputs_r], [z_mean, z_log_var, z, r_mean, r_log_var, r, pz_mean], name='encoder')
plot_model(encoder, show_shapes=True, dpi=300)
plot_model(encoder, to_file=filepath+'encoder_graph.png', show_shapes=True, dpi=100)
# Out:
# 2023-10-12 20:33:30.578106: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Decoder

# %%
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
inter_y1 = Dense(dim_layer3, activation=activation_function)(latent_inputs)
inter_y2 = Dense(dim_layer2, activation=activation_function)(inter_y1)
inter_y3 = Dense(dim_layer1, activation=activation_function)(inter_y2)
outputs = Dense(original_dim)(inter_y3)

decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, show_shapes=True, dpi=80)
plot_model(decoder, to_file=filepath+'decoder_graph.png', show_shapes=True, dpi=100)
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 10)]              0
#
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 286)               36894
#
# =================================================================
# Total params: 47,678
# Trainable params: 47,678
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **combine encoder and decoder to VAE model and print summary**

# %%
outputs = decoder(encoder([inputs_x,inputs_r])[2])
vae = Model([inputs_x,inputs_r], outputs, name='vae_regression')
vae.summary()
# Out:
# Model: "vae_regression"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 286)]        0           []
#
#  ground_truth (InputLayer)      [(None, 1)]          0           []
#
#  encoder (Functional)           [(None, 10),         47818       ['encoder_input[0][0]',
#                                  (None, 10),                      'ground_truth[0][0]']
#                                  (None, 10),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 10)]
#
#  decoder (Functional)           (None, 286)          47678       ['encoder[0][2]']
#
# ==================================================================================================
# Total params: 95,496
# Trainable params: 95,496
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Define loss function**

# %%
reconstruction_loss = mse(inputs_x,outputs)*original_dim*reconstruction_loss_factor

kl_loss = 1 + z_log_var - K.square(z_mean-pz_mean) - K.exp(z_log_var)
kl_loss = -0.5*K.sum(kl_loss, axis=-1)

label_loss = (K.tf.divide(0.5*K.square(r_mean - inputs_r), K.exp(r_log_var)) +  0.5 * r_log_var)
vae_loss = K.mean(reconstruction_loss+kl_loss+label_loss)

vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
vae.save_weights(filepath+'random_weights.h5')
# Out:
# Model: "vae_regression"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 286)]        0           []
#
#  ground_truth (InputLayer)      [(None, 1)]          0           []
#
#  encoder (Functional)           [(None, 10),         47818       ['encoder_input[0][0]',
#                                  (None, 10),                      'ground_truth[0][0]']
#                                  (None, 10),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 10)]
#
#  decoder (Functional)           (None, 286)          47678       ['encoder[0][2]']
#
#  encoder_intermediate (Dense)   (None, 128)          36736       ['encoder_input[0][0]']
#
#  encoder_intermediate_2 (Dense)  (None, 64)          8256        ['encoder_intermediate[0][0]']
#
#  encoder_intermediate_3 (Dense)  (None, 32)          2080        ['encoder_intermediate_2[0][0]']
#
#  r_mean (Dense)                 (None, 1)            33          ['encoder_intermediate_3[0][0]']
#
#  r_log_var (Dense)              (None, 1)            33          ['encoder_intermediate_3[0][0]']
#
#  r (Lambda)                     (None, 1)            0           ['r_mean[0][0]',
#                                                                   'r_log_var[0][0]']
#
#  z_mean (Dense)                 (None, 10)           330         ['encoder_intermediate_3[0][0]']
#
#  pz_mean (Dense)                (None, 10)           20          ['r[0][0]']
#
#  z_log_var (Dense)              (None, 10)           330         ['encoder_intermediate_3[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 10)           0           ['z_mean[0][0]',
#                                                                   'pz_mean[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (None, 286)         0           ['decoder[0][0]']
#  da)
#
#  tf.cast (TFOpLambda)           (None, 286)          0           ['encoder_input[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 10)          0           ['z_log_var[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 10)           0           ['tf.math.subtract[0][0]']
#
#  tf.math.squared_difference (TF  (None, 286)         0           ['tf.convert_to_tensor[0][0]',
#  OpLambda)                                                        'tf.cast[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 10)          0           ['tf.__operators__.add[0][0]',
#  )                                                                'tf.math.square[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 10)           0           ['z_log_var[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 1)           0           ['r_mean[0][0]',
#  )                                                                'ground_truth[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None,)             0           ['tf.math.squared_difference[0][0
#  a)                                                              ]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 10)          0           ['tf.math.subtract_1[0][0]',
#  )                                                                'tf.math.exp[0][0]']
#
#  tf.math.square_1 (TFOpLambda)  (None, 1)            0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None,)              0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1)           0           ['tf.math.square_1[0][0]']
#  )
#
#  tf.math.exp_1 (TFOpLambda)     (None, 1)            0           ['r_log_var[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.multiply[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.math.truediv (TFOpLambda)   (None, 1)            0           ['tf.math.multiply_3[0][0]',
#                                                                   'tf.math.exp_1[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1)           0           ['r_log_var[0][0]']
#  )
#
#  tf.__operators__.add_2 (TFOpLa  (None,)             0           ['tf.math.multiply_1[0][0]',
#  mbda)                                                            'tf.math.multiply_2[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1)           0           ['tf.math.truediv[0][0]',
#  mbda)                                                            'tf.math.multiply_4[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, None)        0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  ()                  0           ['tf.__operators__.add_3[0][0]']
#  bda)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean_1[0][0]']
#
# ==================================================================================================
# Total params: 95,496
# Trainable params: 95,496
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Prepare data**

# %%
X = cf.reshape_data_for_clustering(z500)
y = pr_boxcox_spatial

X_train_1, X_test_1, y_train, y_test = train_test_split(z500.values, y, test_size=0.33)

nt,ny,nx = X_train_1.shape
X_train = np.reshape(X_train_1, [nt, ny*nx], order='F')

nt,ny,nx = X_test_1.shape
X_test = np.reshape(X_test_1, [nt, ny*nx], order='F')

# %% [markdown]
# **Evaluate convergence of loss function on test-train data split**

# %%
vae.load_weights(filepath+'random_weights.h5')
history = vae.fit([X_train,y_train], [X_train,y_train], epochs=epochs, batch_size=batch_size, validation_data=([X_test,y_test], [X_test,y_test]))
# Out:
# Epoch 1/100
# 132/132 [==============================] - 2s 7ms/step - loss: 17.9121 - val_loss: 12.9819
# Epoch 2/100
# 132/132 [==============================] - 1s 5ms/step - loss: 12.1110 - val_loss: 11.4730
# Epoch 3/100
# 132/132 [==============================] - 1s 5ms/step - loss: 11.1820 - val_loss: 10.9422
# Epoch 4/100
# 132/132 [==============================] - 1s 5ms/step - loss: 10.9069 - val_loss: 10.7204
# Epoch 5/100
# 132/132 [==============================] - 1s 5ms/step - loss: 10.6249 - val_loss: 10.5939
# Epoch 6/100
# 132/132 [==============================] - 1s 5ms/step - loss: 10.5267 - val_loss: 10.5640
# Epoch 7/100
# 132/132 [==============================] - 1s 5ms/step - loss: 10.4396 - val_loss: 10.5224
# Epoch 8/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.3306 - val_loss: 10.3418
# Epoch 9/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.2609 - val_loss: 10.2253
# Epoch 10/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.1400 - val_loss: 10.2632
# Epoch 11/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.1557 - val_loss: 10.1548
# Epoch 12/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.0331 - val_loss: 10.2313
# Epoch 13/100
# 132/132 [==============================] - 1s 4ms/step - loss: 10.0309 - val_loss: 10.1670
# Epoch 14/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.9683 - val_loss: 9.9885
# Epoch 15/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.9408 - val_loss: 9.9800
# Epoch 16/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.9415 - val_loss: 9.9752
# Epoch 17/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.8617 - val_loss: 9.9421
# Epoch 18/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.7770 - val_loss: 9.8582
# Epoch 19/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.7852 - val_loss: 9.9559
# Epoch 20/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.7854 - val_loss: 9.8737
# Epoch 21/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.7868 - val_loss: 9.8526
# Epoch 22/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.7187 - val_loss: 9.8823
# Epoch 23/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.6647 - val_loss: 9.8230
# Epoch 24/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.7036 - val_loss: 9.8595
# Epoch 25/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.6447 - val_loss: 9.8530
# Epoch 26/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.6078 - val_loss: 9.8103
# Epoch 27/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.6090 - val_loss: 9.8735
# Epoch 28/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.6086 - val_loss: 9.7852
# Epoch 29/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.5784 - val_loss: 9.7313
# Epoch 30/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.5740 - val_loss: 9.7113
# Epoch 31/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.5394 - val_loss: 9.7950
# Epoch 32/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.5413 - val_loss: 9.8439
# Epoch 33/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.5250 - val_loss: 9.6962
# Epoch 34/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.5020 - val_loss: 9.6587
# Epoch 35/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4317 - val_loss: 9.7148
# Epoch 36/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4315 - val_loss: 9.8438
# Epoch 37/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4806 - val_loss: 9.6536
# Epoch 38/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4640 - val_loss: 9.7348
# Epoch 39/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4458 - val_loss: 9.7167
# Epoch 40/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.4180 - val_loss: 9.6598
# Epoch 41/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.4138 - val_loss: 9.6116
# Epoch 42/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.3719 - val_loss: 9.6544
# Epoch 43/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.3715 - val_loss: 9.7471
# Epoch 44/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.3490 - val_loss: 9.6038
# Epoch 45/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.3439 - val_loss: 9.6292
# Epoch 46/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.3324 - val_loss: 9.6137
# Epoch 47/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.3007 - val_loss: 9.7294
# Epoch 48/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.3205 - val_loss: 9.6475
# Epoch 49/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2648 - val_loss: 9.7534
# Epoch 50/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.3643 - val_loss: 9.6453
# Epoch 51/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2241 - val_loss: 9.7611
# Epoch 52/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.2438 - val_loss: 9.6505
# Epoch 53/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2835 - val_loss: 9.6803
# Epoch 54/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2172 - val_loss: 9.6269
# Epoch 55/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2017 - val_loss: 9.7038
# Epoch 56/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1768 - val_loss: 9.6546
# Epoch 57/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2027 - val_loss: 9.5893
# Epoch 58/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1746 - val_loss: 9.8016
# Epoch 59/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1728 - val_loss: 9.6139
# Epoch 60/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1545 - val_loss: 9.6549
# Epoch 61/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1805 - val_loss: 9.6220
# Epoch 62/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1107 - val_loss: 9.6025
# Epoch 63/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0825 - val_loss: 9.7070
# Epoch 64/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1449 - val_loss: 9.7482
# Epoch 65/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0939 - val_loss: 9.7113
# Epoch 66/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.1158 - val_loss: 9.7637
# Epoch 67/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0694 - val_loss: 9.8419
# Epoch 68/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0683 - val_loss: 9.7863
# Epoch 69/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.0614 - val_loss: 9.7717
# Epoch 70/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.0424 - val_loss: 9.7517
# Epoch 71/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.0140 - val_loss: 9.6990
# Epoch 72/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.0081 - val_loss: 9.6941
# Epoch 73/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0594 - val_loss: 9.7921
# Epoch 74/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0300 - val_loss: 9.7241
# Epoch 75/100
# 132/132 [==============================] - 1s 5ms/step - loss: 9.0486 - val_loss: 9.6729
# Epoch 76/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.0168 - val_loss: 9.7138
# Epoch 77/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.9578 - val_loss: 9.7898
# Epoch 78/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.9270 - val_loss: 9.8227
# Epoch 79/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9587 - val_loss: 9.8060
# Epoch 80/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9370 - val_loss: 9.7788
# Epoch 81/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9698 - val_loss: 9.7359
# Epoch 82/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9686 - val_loss: 9.8598
# Epoch 83/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9809 - val_loss: 9.8663
# Epoch 84/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.9144 - val_loss: 9.7926
# Epoch 85/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.9424 - val_loss: 9.9772
# Epoch 86/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.9029 - val_loss: 9.8426
# Epoch 87/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.9226 - val_loss: 9.9021
# Epoch 88/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.8551 - val_loss: 9.8560
# Epoch 89/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.8870 - val_loss: 9.8023
# Epoch 90/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.8182 - val_loss: 9.9191
# Epoch 91/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8846 - val_loss: 9.8486
# Epoch 92/100
# 132/132 [==============================] - 1s 6ms/step - loss: 8.8769 - val_loss: 10.1181
# Epoch 93/100
# 132/132 [==============================] - 1s 4ms/step - loss: 8.8857 - val_loss: 9.7966
# Epoch 94/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8743 - val_loss: 10.0814
# Epoch 95/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8128 - val_loss: 10.0328
# Epoch 96/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8123 - val_loss: 9.9361
# Epoch 97/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.7901 - val_loss: 10.1115
# Epoch 98/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8383 - val_loss: 10.0049
# Epoch 99/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.8099 - val_loss: 10.0411
# Epoch 100/100
# 132/132 [==============================] - 1s 5ms/step - loss: 8.7757 - val_loss: 10.0385

# %%
fig, ax = plt.subplots(figsize=(16,9), dpi=300)
plt.title(label='Model Loss by Epoch', loc='center')

ax.plot(history.history['loss'], label='Training Data', color='black')
ax.plot(history.history['val_loss'], label='Test Data', color='red')
ax.set(xlabel='Epoch', ylabel='Loss')
plt.xticks(ticks=np.arange(len(history.history['loss']), step=1), labels=np.arange(1, len(history.history['loss'])+1, step=1))
plt.legend()
plt.show()
fig.savefig(filepath+'loss_function.png')

# %% [markdown]
# **Load random weights and train on entire dataset**

# %%
vae.load_weights(filepath+'random_weights.h5')
vae.fit([z500_reshaped,pr_boxcox_spatial],
         epochs=epochs,
         batch_size=batch_size,
         verbose = 1)
 
[z_mean, z_log_var, z, r_mean, r_log_var, r_vae, pz_mean] = encoder.predict([z500_reshaped,pr_boxcox_spatial],batch_size=batch_size)
# Out:
# Epoch 1/100
# 197/197 [==============================] - 1s 3ms/step - loss: 15.0508
# Epoch 2/100
# 197/197 [==============================] - 1s 4ms/step - loss: 11.7127
# Epoch 3/100
# 197/197 [==============================] - 1s 3ms/step - loss: 11.0563
# Epoch 4/100
# 197/197 [==============================] - 1s 3ms/step - loss: 10.7071
# Epoch 5/100
# 197/197 [==============================] - 1s 4ms/step - loss: 10.5449
# Epoch 6/100
# 197/197 [==============================] - 1s 4ms/step - loss: 10.4061
# Epoch 7/100
# 197/197 [==============================] - 1s 3ms/step - loss: 10.3120
# Epoch 8/100
# 197/197 [==============================] - 1s 3ms/step - loss: 10.2471
# Epoch 9/100
# 197/197 [==============================] - 1s 4ms/step - loss: 10.1230
# Epoch 10/100
# 197/197 [==============================] - 1s 3ms/step - loss: 10.0818
# Epoch 11/100
# 197/197 [==============================] - 1s 4ms/step - loss: 10.0116
# Epoch 12/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.9750
# Epoch 13/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.9000
# Epoch 14/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.8918
# Epoch 15/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.8087
# Epoch 16/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.8178
# Epoch 17/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.7206
# Epoch 18/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.7107
# Epoch 19/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.6761
# Epoch 20/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.6715
# Epoch 21/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.6515
# Epoch 22/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.6022
# Epoch 23/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.6113
# Epoch 24/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.5643
# Epoch 25/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.5065
# Epoch 26/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.5420
# Epoch 27/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.4805
# Epoch 28/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.4370
# Epoch 29/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.4910
# Epoch 30/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.4533
# Epoch 31/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.4103
# Epoch 32/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.3976
# Epoch 33/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.4180
# Epoch 34/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3769
# Epoch 35/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3337
# Epoch 36/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3274
# Epoch 37/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3050
# Epoch 38/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3184
# Epoch 39/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.2800
# Epoch 40/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.3042
# Epoch 41/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.2673
# Epoch 42/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.2813
# Epoch 43/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.2287
# Epoch 44/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.2415
# Epoch 45/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.2139
# Epoch 46/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.2080
# Epoch 47/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.2119
# Epoch 48/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1654
# Epoch 49/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1792
# Epoch 50/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1663
# Epoch 51/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1771
# Epoch 52/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1588
# Epoch 53/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1312
# Epoch 54/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1074
# Epoch 55/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0840
# Epoch 56/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0897
# Epoch 57/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.1003
# Epoch 58/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0853
# Epoch 59/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0989
# Epoch 60/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0924
# Epoch 61/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0312
# Epoch 62/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0639
# Epoch 63/100
# 197/197 [==============================] - 1s 3ms/step - loss: 9.0489
# Epoch 64/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.0375
# Epoch 65/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9850
# Epoch 66/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9985
# Epoch 67/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.0271
# Epoch 68/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9904
# Epoch 69/100
# 197/197 [==============================] - 1s 4ms/step - loss: 9.0342
# Epoch 70/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9562
# Epoch 71/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9875
# Epoch 72/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9585
# Epoch 73/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.9645
# Epoch 74/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.9580
# Epoch 75/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.9322
# Epoch 76/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.9960
# Epoch 77/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8982
# Epoch 78/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8785
# Epoch 79/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.9045
# Epoch 80/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8953
# Epoch 81/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8888
# Epoch 82/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.9146
# Epoch 83/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8779
# Epoch 84/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8626
# Epoch 85/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8500
# Epoch 86/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8448
# Epoch 87/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8491
# Epoch 88/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8067
# Epoch 89/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8478
# Epoch 90/100
# 197/197 [==============================] - 1s 4ms/step - loss: 8.8608
# Epoch 91/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8649
# Epoch 92/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8220
# Epoch 93/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8427
# Epoch 94/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8456
# Epoch 95/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.7859
# Epoch 96/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.7764
# Epoch 97/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.7911
# Epoch 98/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8143
# Epoch 99/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.8036
# Epoch 100/100
# 197/197 [==============================] - 1s 3ms/step - loss: 8.7689
# 197/197 [==============================] - 0s 2ms/step

# %% [markdown]
# **Apply trained model**

# %%
X_encoded = encoder.predict([X,y])
X_decoded = decoder.predict(X_encoded[2])
# Out:
# 393/393 [==============================] - 1s 1ms/step
# 393/393 [==============================] - 0s 828us/step

# %% [markdown]
# **Reconstruct flattened data to xarray lat-lon**

# %%
reconstructed = X_decoded.reshape(X_decoded.shape[0], inputdim2, inputdim1)
reconstructed = np.transpose(reconstructed, (0, 2, 1))
reconstructed_xr = xr.DataArray(reconstructed, coords=z500[0:X_decoded.shape[0], :, :].coords, 
                         dims=z500[0:X_decoded.shape[0], :, :].dims, attrs=z500[0:X_decoded.shape[0], :, :].attrs)

# %% [markdown]
# **Cluster center and odds ratio visualisation**

# %%
k=5
z500_clusters_vae = KMeans(n_clusters=k, random_state=0).fit(X_encoded[2])

cluster_centers_decoded = decoder.predict(z500_clusters_vae.cluster_centers_).reshape(k, inputdim2, inputdim1)
cluster_centers_decoded = np.transpose(cluster_centers_decoded, (0, 2, 1))

cluster_centers_decoded_xr = xr.DataArray(cluster_centers_decoded, coords=z500[0:k, :, :].coords, 
                         dims=z500[0:k, :, :].dims, attrs=z500[0:k, :, :].attrs)
# Out:
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# **Relabel labels**

# %%
pr_labeled = cf.assign_labels(xarray_array=pr, labels=z500_clusters_vae.labels_)
pr_by_label = pr_labeled.groupby('label').mean(dim=['time', 'latitude', 'longitude'])
cluster_order = np.flip(np.argsort(pr_by_label.values)).tolist()

dict_replace = {0: cluster_order.index(0), 1: cluster_order.index(1), 2: cluster_order.index(2), 
                3: cluster_order.index(3), 4:cluster_order.index(4)}

def replace(element):
    return dict_replace.get(element, element)

vfunc = np.vectorize(replace)

relabeled_labels = vfunc(z500_clusters_vae.labels_)

d = {'Labels': 'R-VAE', 'Value': relabeled_labels}
df = pd.DataFrame(data=d)
df.to_csv(filepath+'relabeled_labels.csv')

# %%
clusters_vis = cf.visualise_contourplot(dataset_xarray = cluster_centers_decoded_xr, 
                                                          unit = '[m]', 
                                                          cluster_results = z500_clusters_vae, 
                                        cluster_order=cluster_order,
                                                          regime_names = ['Regime 1', 'Regime 2', 'Regime 3',
                                                                         'Regime 4', 'Regime 5', 'Regime 6',
                                                                         'Regime 7', 'Regime 8'],
                                                          vmin=-1.7, vmax=1.7, steps=0.2, col_number = 5,
                                                          color_scheme = 'RdBu_r', borders=False,
                                         projection = ccrs.PlateCarree(central_longitude=0))

plt.savefig(filepath+'cluster_visualisation_5.png')

# %%
def calculate_conditional_probability_change(threshold_matrix, kmeans, comparison, shift_value=0):
    
    # add cluster assignment to threshold vector
    threshold_matrix_label = threshold_matrix.assign_coords(label=("time", np.roll(kmeans.labels_, shift_value)))

    # probability conditional on weather type
    n_wr = threshold_matrix_label.groupby('label').mean()

    # overall probability
    n_total = threshold_matrix_label.mean(dim='time')
    
    if comparison=='difference':
        ds = n_wr - n_total
    elif comparison=='ratio':
        ds = n_wr/n_total
    elif comparison=='none':
        ds = n_wr
    else:
        print('invalid entry for diff_or_quot')
    
    return(ds)

# %%
pr_qn95_ratio = calculate_conditional_probability_change(threshold_matrix = threshold_qn95, 
                                                        kmeans = z500_clusters_vae,
                                                       comparison = 'ratio', shift_value=0)

pr_qn95_vis = cf.visualise_spatial_oddsratio(dataset_xarray = pr_qn95_ratio, unit='',
                                               cluster_order=cluster_order,
                                   color_scheme = 'GnBu', vmin = 0, vmax=6, steps=7, 
                                   title = 'Odds ratio of 95th percentile precipitation',
                                             regime_names = ['Regime 1', 'Regime 2', 'Regime 3',
                                                                         'Regime 4', 'Regime 5', 'Regime 6',
                                                                         'Regime 7', 'Regime 8'],
                                   borders=True, projection=ccrs.PlateCarree(central_longitude=0), col_number=5)

plt.savefig(filepath+'oddsratio_95_5.png')

# %% [markdown]
# ### regular evaluation continues

# %%
tsne = TSNE(n_components=2, random_state=0, perplexity=10)
X_2d = tsne.fit_transform(X_encoded[2])

# %%
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=relabeled_labels, s=7)
plt.title('Latent Space Representation Basic VAE + latent clusters')
#plt.legend(*scatter.legend_elements())
plt.savefig(filepath+'tsne_latent.png')

# %%
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=pr_spatial.values, cmap='GnBu', s=5, alpha=1)
plt.title('Latent Space Representation - precipitation')
#plt.legend(*scatter.legend_elements(), loc='upper right')
plt.savefig(filepath+'tsne_precipitation_nolegend.png')

# %%
mse = mean_squared_error(X_decoded, z500_reshaped, multioutput='raw_values')

mse_reshaped = mse.reshape(ny,nx, order='F')
mse_reshaped_xr = xr.DataArray(mse_reshaped, coords=z500[0, :, :].coords, 
                     dims=z500[0, :, :].dims, attrs=z500[0, :, :].attrs)

fig = plt.figure(figsize=[14,3])
ax1 = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=0))
mse_reshaped_xr.plot(ax=ax1, cmap='Reds', transform=ccrs.PlateCarree(), vmin=0, vmax=0.6)
ax1.coastlines()
ax1.add_feature(cartopy.feature.BORDERS)
ax1.set_title('MSE - R-VAE v2')
plt.tight_layout()
plt.savefig(filepath+'reconstructed_mse.png')
